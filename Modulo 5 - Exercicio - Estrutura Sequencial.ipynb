# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print ('Alo Mundo')
# Out:
# Alo Mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
número = input("O número informadoo foi")
print (f"O Número informado foi {número}")
# Out:
# O Número informado foi 10

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
v1 = int(input('primeiro valor?'))
v2 = int(input('segundo valor?'))
print (f"{v1} + {v2} = {v1+v2}")
# Out:
# 10 + 40 = 50

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
primeiro_b = int(input('Nota do Primeiro bimestre?'))
segundo_b = int(input('Nota do Segundo bimestre?'))
terceiro_b = int(input('Nota do Terceiro bimestre?'))
quarto_b = int(input('Nota do Quarto bimestre?'))
soma = primeiro_b + segundo_b + terceiro_b + quarto_b
print (f"{soma / 4} seria a média de todas as notas")
# Out:
# 5.75 seria a média de todas as notas

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
valor_cm = float(input('Quantos metros?'))
print(f"{valor_cm} metros são: {valor_cm * 100} Centímetros'")
# Out:
# 1.8 metros são: 180.0 Centímetros'

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input ('Qual seria a largura?'))
comprimento = float(input ('Qual seria o comprimento?'))
soma = largura * comprimento
print(f"Com {largura} de largura e {comprimento} de comprimento, temos {soma} metros quadrados")
# Out:
# Com 2.5 de largura e 5.7 de comprimento, temos 14.25 metros quadrados

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganho_hora = float(input('Quanto você recebe por hora?'))
trabalho_hora = float(input('Quantas horas de trabalho?'))
dia_trabalho = ganho_hora * trabalho_hora
soma = dia_trabalho * 21

if soma < 1300:
    print("cuidado você está sendo escravizado!")

else:
    print (f"Se você trabalha {trabalho_hora} por dia, recebendo {ganho_hora} por hora, seu salário é {soma}")
# Out:
# Se você trabalha 7.0 por dia, recebendo 12.5 por hora, seu salário é 1837.5

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
valor_f = float(input('Medição Fahrenheit?'))
conversao = ((valor_f - 32) / 1.8)
print(f"A conversão de {valor_f} Fahrenheit para Celsius é: {conversao} C°")
# Out:
# A conversão de 200.5 Fahrenheit para Celsius é: 93.61111111111111 C°

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
valor_c = float(input('Medição Celsius?'))
conversao = ((valor_c + 32) * 1.8)
print(f"A conversão de {valor_c} Celsius para Fahrenheit é: {conversao} F°")

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input('Qual sua altura?'))
calculo = ((72.7*altura)-58)
print(f"O Peso ideal para sua altura é de: {calculo}")

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
altura = float(input('Qual sua altura?'))
sexo = input('Digite o seu sexo (M para masculino e F para Feminino):')
calculo_m = ((72.7*altura)-58)
calculo_f = ((62.1*altura)-44.7)

if(sexo == 'M'):
    print(f"O Peso ideal para sua altura é de: {calculo_m}")

else:
    print(f"O Peso ideal para sua altura é de: {calculo_f}")

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
ganho_hora = float(input('Quanto você recebe por hora?'))
trabalho_hora = float(input('Quantas horas de trabalho?'))

print(f" Ganho por hora R$ {ganho_hora}, com {trabalho_hora} horas trabalhadas")

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
dia_trabalho = ganho_hora * trabalho_hora
salario_bruto = dia_trabalho * 21
print(f"R$ {salario_bruto}")

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
porcentagem = 11
desconto_ir = (porcentagem / 100) * salario_bruto
print(f"O valor do IR é: R$ {desconto_ir:.2f}")

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
porcentagem = 8
desconto_inss = (porcentagem / 100) * salario_bruto
print(f"O valor do INSS é: R$ {desconto_inss:.2f}")

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
porcentagem = 5
desconto_sind = (porcentagem / 100) * salario_bruto
print(f"O valor do Sindicato é: R$ {desconto_sind:.2f}")

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario_bruto - desconto_sind - desconto_inss - desconto_ir
print(f"Se você recebe R$ {salario_bruto}, após os descontos, seu salário Líquido é de: R$ {salario_liquido}")

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
tamanho = float(input('Informe o tamanho da área a ser pintada em metros cúbicos: '))

litros_tinta = tamanho / 3 

latas = litros_tinta / 18
preco = latas * 80
print(f'Serão necessárias {latas} latas, custando R$ {preco} no total')
# Out:
# Serão necessárias 0.3703703703703704 latas, custando R$ 29.629629629629633 no total

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input('Informe o tamanho do arquivo em MB?: '))
velocidade = float(input('Qual velocidade da conexão em Mbps?: '))

#conversao megabytes > megabits
tamanho_megabits = tamanho * 8

tempo = tamanho_megabits / velocidade
tempo_minutos = tempo / 60
print(f'O tempo de download é de {tempo_minutos} minutos')
# Out:
# O tempo de download é de 6.666666666666667 minutos
